# %% [markdown]
# <a href="https://colab.research.google.com/github/fwang312/Supervised-learning/blob/master/Health_Insurance_Cost_Prediction_Final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 1.Project Introduction

# %% [markdown]
# The objective of this case study is to predict the health insurance cost incurred by Individuals based on their age, gender, BMI, number of children, smoking habit and geo-location.
#
# 本案例研究的目的是根据年龄，性别，BMI，儿童数量，吸烟习惯和地理位置来预测个人承担的健康保险费用。

# %% [markdown]
# - Features available are:
#
#     - sex: insurance contractor gender, female, male
#
#     - bmi: Body mass index (ideally 18.5 to 24.9)
#
#     - children: Number of children covered by health insurance / Number of dependents
#
#     - smoker: smoking habits
#
#     - region: the beneficiary's residential area in the US, northeast, southeast, southwest, northwest.
#
#     - charges: Individual medical costs billed by health insurance
#
#
# Data Source:https://www.kaggle.com/mirichoi0218/insurance

# %% [markdown]
# ## 2.Load the Dataset and Libraries

# %%
from google.colab import drive
drive.mount('/content/gdrive')

import os
os.chdir("/content/gdrive/My Drive/Project/Insurance Cost ")
# !ls
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive
# 'back up final of Final.Health Insurance Cost Prediction.ipynb'
# 'Final.Health Insurance Cost Prediction.ipynb'
# 'Health Insurance Cost Prediction.ipynb'
#  insurance.csv
#  medical_insurance_prediction_notebook.ipynb
# 'V2.Health Insurance Cost Prediction.ipynb'

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt


from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import r2_score,mean_squared_error
from sklearn.ensemble import RandomForestRegressor
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
df = pd.read_csv("insurance.csv")

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df.tail()
# Out:
#       age     sex    bmi  children smoker     region     charges
# 1333   50    male  30.97         3     no  northwest  10600.5483
# 1334   18  female  31.92         0     no  northeast   2205.9808
# 1335   18  female  36.85         0     no  southeast   1629.8335
# 1336   21  female  25.80         0     no  southwest   2007.9450
# 1337   61  female  29.07         0    yes  northwest  29141.3603

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
# convert categorical variable to numerical

from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# sex
le.fit(df.sex.drop_duplicates())
df.sex = le.transform(df.sex)

# smoke
le.fit(df.smoker.drop_duplicates())
df.smoker = le.transform(df.smoker)

# %%
df.head()
# Out:
#    age  sex     bmi  children  smoker     region      charges
# 0   19    0  27.900         0       1  southwest  16884.92400
# 1   18    1  33.770         1       0  southeast   1725.55230
# 2   28    1  33.000         3       0  southeast   4449.46200
# 3   33    1  22.705         0       0  northwest  21984.47061
# 4   32    1  28.880         0       0  northwest   3866.85520

# %%
# Check unique values in 'region' column
df['region'].unique()
# Out:
# array(['southwest', 'southeast', 'northwest', 'northeast'], dtype=object)

# %%
region_dummies = pd.get_dummies(df['region'], drop_first = True)
region_dummies.head()
# Out:
#    northwest  southeast  southwest
# 0          0          0          1
# 1          0          1          0
# 2          0          1          0
# 3          1          0          0
# 4          1          0          0

# %%
df = pd.concat([df, region_dummies], axis = 1)

# %%
df.drop(['region'], axis = 1, inplace = True)

# %%
df.head()
# Out:
#    age  sex     bmi  children  ...      charges  northwest  southeast  southwest
# 0   19    0  27.900         0  ...  16884.92400          0          0          1
# 1   18    1  33.770         1  ...   1725.55230          0          1          0
# 2   28    1  33.000         3  ...   4449.46200          0          1          0
# 3   33    1  22.705         0  ...  21984.47061          1          0          0
# 4   32    1  28.880         0  ...   3866.85520          1          0          0
#
# [5 rows x 9 columns]

# %% [markdown]
# ## 3.Exploratory Data Analysis

# %%
# Check NA values
df.isnull().sum()
# Out:
# age          0
# sex          0
# bmi          0
# children     0
# smoker       0
# charges      0
# northwest    0
# southeast    0
# southwest    0
# dtype: int64

# %%
# Check the DataFrame Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        1338 non-null   int64
#  1   sex        1338 non-null   int64
#  2   bmi        1338 non-null   float64
#  3   children   1338 non-null   int64
#  4   smoker     1338 non-null   int64
#  5   charges    1338 non-null   float64
#  6   northwest  1338 non-null   uint8
#  7   southeast  1338 non-null   uint8
#  8   southwest  1338 non-null   uint8
# dtypes: float64(2), int64(4), uint8(3)
# memory usage: 66.8 KB

# %% [markdown]
# The people in the southeast have the highest insurance charges and obviously, with the highest BMI index.

# %%
## group by region

# %%
# Group the Age to see the relationship between age and charges
df_age = df.groupby(by = 'age').mean()
df_age
# Out:
#           sex        bmi  children  ...  northwest  southeast  southwest
# age                                 ...
# 18   0.521739  31.326159  0.449275  ...   0.000000   0.536232   0.000000
# 19   0.514706  28.596912  0.426471  ...   0.500000   0.044118   0.455882
# 20   0.517241  30.632759  0.862069  ...   0.241379   0.275862   0.275862
# 21   0.535714  28.185714  0.785714  ...   0.250000   0.250000   0.250000
# 22   0.535714  31.087679  0.714286  ...   0.250000   0.285714   0.214286
# 23   0.500000  31.454464  1.000000  ...   0.250000   0.250000   0.250000
# 24   0.500000  29.142679  0.464286  ...   0.250000   0.250000   0.250000
# 25   0.535714  29.693929  1.285714  ...   0.250000   0.250000   0.250000
# 26   0.535714  29.428929  1.071429  ...   0.250000   0.250000   0.250000
# 27   0.500000  29.333571  0.964286  ...   0.214286   0.321429   0.214286
# 28   0.500000  29.482143  1.285714  ...   0.214286   0.285714   0.250000
# 29   0.518519  29.383148  1.259259  ...   0.259259   0.259259   0.222222
# 30   0.518519  30.557593  1.555556  ...   0.222222   0.296296   0.259259
# 31   0.518519  29.918333  1.407407  ...   0.259259   0.259259   0.222222
# 32   0.500000  31.597692  1.269231  ...   0.269231   0.307692   0.230769
# 33   0.500000  31.163077  1.538462  ...   0.230769   0.307692   0.269231
# 34   0.500000  30.274038  1.153846  ...   0.230769   0.230769   0.269231
# 35   0.520000  31.394800  1.680000  ...   0.240000   0.240000   0.280000
# 36   0.520000  29.374200  1.240000  ...   0.240000   0.280000   0.200000
# 37   0.520000  31.216600  1.520000  ...   0.280000   0.240000   0.240000
# 38   0.480000  28.996600  1.480000  ...   0.240000   0.280000   0.240000
# 39   0.480000  29.910200  2.200000  ...   0.240000   0.240000   0.280000
# 40   0.518519  30.139074  1.592593  ...   0.259259   0.296296   0.185185
# 41   0.518519  31.506852  1.407407  ...   0.259259   0.296296   0.222222
# 42   0.518519  30.328148  1.000000  ...   0.222222   0.296296   0.259259
# 43   0.481481  30.204444  1.629630  ...   0.185185   0.296296   0.259259
# 44   0.481481  30.844259  1.222222  ...   0.259259   0.296296   0.222222
# 45   0.517241  29.778966  1.482759  ...   0.241379   0.241379   0.275862
# 46   0.517241  31.340862  1.620690  ...   0.241379   0.241379   0.241379
# 47   0.482759  30.664310  1.379310  ...   0.206897   0.310345   0.241379
# 48   0.482759  31.925690  1.310345  ...   0.241379   0.310345   0.206897
# 49   0.500000  30.313929  1.500000  ...   0.250000   0.250000   0.250000
# 50   0.517241  31.132241  1.310345  ...   0.241379   0.241379   0.275862
# 51   0.482759  31.727069  1.103448  ...   0.206897   0.310345   0.241379
# 52   0.482759  32.936034  1.482759  ...   0.275862   0.241379   0.241379
# 53   0.500000  30.360893  1.250000  ...   0.250000   0.250000   0.250000
# 54   0.500000  31.234286  1.428571  ...   0.250000   0.250000   0.250000
# 55   0.500000  31.950000  0.961538  ...   0.230769   0.269231   0.269231
# 56   0.500000  31.600962  0.769231  ...   0.230769   0.230769   0.269231
# 57   0.500000  30.844423  0.615385  ...   0.269231   0.230769   0.230769
# 58   0.480000  32.718200  0.240000  ...   0.280000   0.240000   0.240000
# 59   0.480000  30.572000  1.200000  ...   0.200000   0.320000   0.240000
# 60   0.521739  30.332826  0.347826  ...   0.217391   0.260870   0.260870
# 61   0.478261  32.548261  0.739130  ...   0.260870   0.217391   0.260870
# 62   0.478261  32.342609  0.565217  ...   0.260870   0.260870   0.217391
# 63   0.478261  31.923478  0.565217  ...   0.260870   0.260870   0.260870
# 64   0.500000  32.976136  0.772727  ...   0.227273   0.363636   0.227273
#
# [47 rows x 8 columns]

# %% [markdown]
# We can get a basic idea that the charges will increase when the age increase.
#
# plot analysis

# %%
df.describe()
# Out:
#                age          sex  ...    southeast    southwest
# count  1338.000000  1338.000000  ...  1338.000000  1338.000000
# mean     39.207025     0.505232  ...     0.272048     0.242900
# std      14.049960     0.500160  ...     0.445181     0.428995
# min      18.000000     0.000000  ...     0.000000     0.000000
# 25%      27.000000     0.000000  ...     0.000000     0.000000
# 50%      39.000000     1.000000  ...     0.000000     0.000000
# 75%      51.000000     1.000000  ...     1.000000     0.000000
# max      64.000000     1.000000  ...     1.000000     1.000000
#
# [8 rows x 9 columns]

# %% [markdown]
# ## 4.Visualzie the dataset

# %%
df[['age', 'sex', 'bmi', 'children', 'smoker', 'charges']].hist(bins = 30, figsize = (10,10), color = 'blue')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f221b61a780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f221b5f2a20>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f221b5a6c88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f221b559ef0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f221b51b198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f221b4cc400>]],
#       dtype=object)

# %%
#plot pairplot
sns.pairplot(df)

# %% [markdown]
# Check the realtionship between the age and Charges, we can see the it is more complex than a linear relationship.
#
# So we will consider some non-linear Algorithim such as ANN or XgBoost.

# %%
# Explore the relation between age and charges
sns.regplot(x = 'age', y = 'charges', data = df)
plt.show()

# %%
# Explore the relation between BMI and charges
sns.regplot(x = 'bmi', y = 'charges', data = df)
plt.show()

# %%
# Check the correlation
corr = df.corr()
corr
# Out:
#                 age       sex       bmi  ...  northwest  southeast  southwest
# age        1.000000 -0.020856  0.109272  ...  -0.000407  -0.011642   0.010016
# sex       -0.020856  1.000000  0.046371  ...  -0.011156   0.017117  -0.004184
# bmi        0.109272  0.046371  1.000000  ...  -0.135996   0.270025  -0.006205
# children   0.042469  0.017163  0.012759  ...   0.024806  -0.023066   0.021914
# smoker    -0.025019  0.076185  0.003750  ...  -0.036945   0.068498  -0.036945
# charges    0.299008  0.057292  0.198341  ...  -0.039905   0.073982  -0.043210
# northwest -0.000407 -0.011156 -0.135996  ...   1.000000  -0.346265  -0.320829
# southeast -0.011642  0.017117  0.270025  ...  -0.346265   1.000000  -0.346265
# southwest  0.010016 -0.004184 -0.006205  ...  -0.320829  -0.346265   1.000000
#
# [9 rows x 9 columns]

# %%
plt.figure(figsize=(8,8))
p = sns.heatmap(df.corr(),cmap="coolwarm",annot=True, square =True)

# %% [markdown]
# Smoke have the most positive relationship with the charges

# %% [markdown]
# ## 5.Split the train test dataset

# %%
df.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'charges', 'northwest',
#        'southeast', 'southwest'],
#       dtype='object')

# %%
X = df.drop(['charges'], axis = 1)
y = df.charges

# %%
X = np.array(X).astype('float32')
y = np.array(y).astype('float32')

# %%
y_reshape = y.reshape(-1,1)

# %%
from sklearn.preprocessing import StandardScaler

scaler_x = StandardScaler()
X_scale = scaler_x.fit_transform(X)

scaler_y = StandardScaler()
y_scale = scaler_y.fit_transform(y_reshape)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_scale,y_scale,test_size = 0.2,random_state = 42)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (1070, 8)
# (268, 8)
# (1070, 1)
# (268, 1)

# %% [markdown]
# ## 6.Linear Regression Model

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error,accuracy_score
from math import sqrt

lr = LinearRegression()
lr.fit(X_train, y_train)

lr_R2 = lr.score(X_test,y_test)
lr_R2
# Out:
# 0.7835929939299844

# %%
# Predict the value
y_pred = lr.predict(X_test)

y_pred_orig = scaler_y.inverse_transform(y_pred)
y_test_orig = scaler_y.inverse_transform(y_test)

# %%
k = X_test.shape[1]
n = len(X_test)

RMSE = float(format(np.sqrt(mean_squared_error(y_test_orig, y_pred_orig)),'.3f'))
MSE = mean_squared_error(y_test_orig, y_pred_orig)
MAE = mean_absolute_error(y_test_orig, y_pred_orig)
r2 = r2_score(y_test_orig, y_pred_orig)
adj_r2 = 1 - (1-r2) * (n-1)/(n-k)

print('RMSE =',RMSE, 
      '\nMSE =',MSE, 
      '\nMAE =',MAE,
      '\nR2=',r2, 
      '\nAdjusted R2 =',adj_r2)
# Out:
# RMSE = 5796.284
# MSE = 33596910.0
# MAE = 4181.194
# R2= 0.7835930057311533
# Adjusted R2 = 0.7777666635777613

# %% [markdown]
# ## 7.Multiple linear regression (Degree = 2)

# %%
quad = PolynomialFeatures (degree = 2)
X_quad = quad.fit_transform(X_scale)

X_train_plr,X_test_plr,y_train_plr,y_test_plr = train_test_split(X_quad,y_scale,test_size = 0.2, random_state = 0)

plr = LinearRegression().fit(X_train_plr,y_train_plr)

plr_R2 = plr.score(X_test_plr,y_test_plr)
plr_R2
# Out:
# 0.8805375648005201

# %%
# Predict the value
y_pred = plr.predict(X_test_plr)

y_pred_orig = scaler_y.inverse_transform(y_pred)
y_test_orig = scaler_y.inverse_transform(y_test_plr)

# %%
k = X_test.shape[1]
n = len(X_test)

RMSE = float(format(np.sqrt(mean_squared_error(y_test_orig, y_pred_orig)),'.3f'))
MSE = mean_squared_error(y_test_orig, y_pred_orig)
MAE = mean_absolute_error(y_test_orig, y_pred_orig)
r2 = r2_score(y_test_orig, y_pred_orig)
adj_r2 = 1 - (1-r2) * (n-1)/(n-k)

print('RMSE =',RMSE, 
      '\nMSE =',MSE, 
      '\nMAE =',MAE,
      '\nR2=',r2, 
      '\nAdjusted R2 =',adj_r2)
# Out:
# RMSE = 4360.052
# MSE = 19010052.0
# MAE = 2934.794
# R2= 0.8805375677105849
# Adjusted R2 = 0.8773212714566391

# %% [markdown]
# ## 8.Deep Learning Model (ANN)

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Dense, Activation, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam

# %%
ANN_model = keras.Sequential()
ANN_model.add(Dense(50, input_dim = 8))
ANN_model.add(Activation('relu'))

ANN_model.add(Dense(180))
ANN_model.add(Activation('relu'))
ANN_model.add(Dropout(0.3))

ANN_model.add(Dense(180))
ANN_model.add(Activation('relu'))
ANN_model.add(Dropout(0.3))

ANN_model.add(Dense(50))
ANN_model.add(Activation('linear'))

ANN_model.add(Dense(1))
ANN_model.compile(loss = 'mse', optimizer = 'adam')
ANN_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 50)                450
# _________________________________________________________________
# activation (Activation)      (None, 50)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 180)               9180
# _________________________________________________________________
# activation_1 (Activation)    (None, 180)               0
# _________________________________________________________________
# dropout (Dropout)            (None, 180)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 180)               32580
# _________________________________________________________________
# activation_2 (Activation)    (None, 180)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 180)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 50)                9050
# _________________________________________________________________
# activation_3 (Activation)    (None, 50)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 51
# =================================================================
# Total params: 51,311
# Trainable params: 51,311
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model and trainning
ANN_model.compile(optimizer= 'Adam', loss='mean_squared_error')
epochs_hist = ANN_model.fit(X_train, y_train, epochs= 50, batch_size = 20, validation_split= 0.2)

result = ANN_model.evaluate(X_test, y_test)
accuracy_ANN = 1 - result
print('Accuracy : {}'.format(accuracy_ANN) )
# Out:
# Epoch 1/50
# 43/43 [==============================] - 0s 7ms/step - loss: 0.4626 - val_loss: 0.2440
# Epoch 2/50
# 43/43 [==============================] - 0s 3ms/step - loss: 0.2606 - val_loss: 0.2183
# Epoch 3/50
# 43/43 [==============================] - 0s 3ms/step - loss: 0.2382 - val_loss: 0.1735
# Epoch 4/50
# 43/43 [==============================] - 0s 3ms/step - loss: 0.2191 - val_loss: 0.1632
# Epoch 5/50
# 43/43 [==============================] - 0s 4ms/step - loss: 0.2042 - val_loss: 0.1557
# Epoch 6/50
# 43/43 [==============================] - 0s 3ms/step - loss: 0.2020 - val_loss: 0.1658
# Epoch 7/50
# 43/43 [==============================] - 0s 3ms/step - loss: 0.1907 - val_loss: 0.1449
# Epoch 8/50
# 43/43 [==============================] - 0s 3ms/step - loss: 0.1926 - val_loss: 0.1661
# Epoch 9/50
# 43/43 [==============================] - 0s 3ms/step - loss: 0.1794 - val_loss: 0.1451
# Epoch 10/50
# 43/43 [==============================] - 0s 3ms/step - loss: 0.1830 - val_loss: 0.1866
# Epoch 11/50
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1788 - val_loss: 0.1517
# Epoch 12/50
# 43/43 [==============================] - 0s 3ms/step - loss: 0.1769 - val_loss: 0.1759
# Epoch 13/50
# 43/43 [==============================] - 0s 3ms/step - loss: 0.1806 - val_loss: 0.1779
# Epoch 14/50
# 43/43 [==============================] - 0s 3ms/step - loss: 0.1750 - val_loss: 0.2095
# Epoch 15/50
# 43/43 [==============================] - 0s 3ms/step - loss: 0.1755 - val_loss: 0.1394
# Epoch 16/50
# 43/43 [==============================] - 0s 3ms/step - loss: 0.1756 - val_loss: 0.1568
# Epoch 17/50
# 43/43 [==============================] - 0s 3ms/step - loss: 0.1637 - val_loss: 0.1713
# Epoch 18/50
# 43/43 [==============================] - 0s 3ms/step - loss: 0.1728 - val_loss: 0.2207
# Epoch 19/50
# 43/43 [==============================] - 0s 3ms/step - loss: 0.1639 - val_loss: 0.1532
# Epoch 20/50
# 43/43 [==============================] - 0s 3ms/step - loss: 0.1654 - val_loss: 0.1442
# Epoch 21/50
# 43/43 [==============================] - 0s 3ms/step - loss: 0.1657 - val_loss: 0.1462
# Epoch 22/50
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1557 - val_loss: 0.1487
# Epoch 23/50
# 43/43 [==============================] - 0s 3ms/step - loss: 0.1552 - val_loss: 0.1518
# Epoch 24/50
# 43/43 [==============================] - 0s 3ms/step - loss: 0.1588 - val_loss: 0.1682
# Epoch 25/50
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1662 - val_loss: 0.1648
# Epoch 26/50
# 43/43 [==============================] - 0s 3ms/step - loss: 0.1469 - val_loss: 0.1562
# Epoch 27/50
# 43/43 [==============================] - 0s 3ms/step - loss: 0.1478 - val_loss: 0.1784
# Epoch 28/50
# 43/43 [==============================] - 0s 3ms/step - loss: 0.1477 - val_loss: 0.1467
# Epoch 29/50
# 43/43 [==============================] - 0s 3ms/step - loss: 0.1572 - val_loss: 0.1792
# Epoch 30/50
# 43/43 [==============================] - 0s 3ms/step - loss: 0.1505 - val_loss: 0.1883
# Epoch 31/50
# 43/43 [==============================] - 0s 3ms/step - loss: 0.1598 - val_loss: 0.1503
# Epoch 32/50
# 43/43 [==============================] - 0s 3ms/step - loss: 0.1521 - val_loss: 0.1620
# Epoch 33/50
# 43/43 [==============================] - 0s 3ms/step - loss: 0.1446 - val_loss: 0.1596
# Epoch 34/50
# 43/43 [==============================] - 0s 3ms/step - loss: 0.1443 - val_loss: 0.1713
# Epoch 35/50
# 43/43 [==============================] - 0s 3ms/step - loss: 0.1415 - val_loss: 0.1451
# Epoch 36/50
# 43/43 [==============================] - 0s 3ms/step - loss: 0.1391 - val_loss: 0.1445
# Epoch 37/50
# 43/43 [==============================] - 0s 3ms/step - loss: 0.1433 - val_loss: 0.1558
# Epoch 38/50
# 43/43 [==============================] - 0s 3ms/step - loss: 0.1339 - val_loss: 0.1616
# Epoch 39/50
# 43/43 [==============================] - 0s 3ms/step - loss: 0.1347 - val_loss: 0.1564
# Epoch 40/50
# 43/43 [==============================] - 0s 3ms/step - loss: 0.1325 - val_loss: 0.1814
# Epoch 41/50
# 43/43 [==============================] - 0s 3ms/step - loss: 0.1275 - val_loss: 0.1720
# Epoch 42/50
# 43/43 [==============================] - 0s 3ms/step - loss: 0.1361 - val_loss: 0.1757
# Epoch 43/50
# 43/43 [==============================] - 0s 3ms/step - loss: 0.1221 - val_loss: 0.1599
# Epoch 44/50
# 43/43 [==============================] - 0s 3ms/step - loss: 0.1327 - val_loss: 0.1600
# Epoch 45/50
# 43/43 [==============================] - 0s 3ms/step - loss: 0.1297 - val_loss: 0.1773
# Epoch 46/50
# 43/43 [==============================] - 0s 3ms/step - loss: 0.1276 - val_loss: 0.1671
# Epoch 47/50
# 43/43 [==============================] - 0s 3ms/step - loss: 0.1304 - val_loss: 0.1940
# Epoch 48/50
# 43/43 [==============================] - 0s 3ms/step - loss: 0.1228 - val_loss: 0.1789
# Epoch 49/50
# 43/43 [==============================] - 0s 3ms/step - loss: 0.1253 - val_loss: 0.2029
# Epoch 50/50
# 43/43 [==============================] - 0s 3ms/step - loss: 0.1266 - val_loss: 0.1606
# 9/9 [==============================] - 0s 1ms/step - loss: 0.1579
# Accuracy : 0.8421158045530319

# %%
epochs_hist.history.keys()
plt.plot(epochs_hist.history['loss'])
plt.plot(epochs_hist.history['val_loss'])
plt.title('Model Loss Progross During Trainning')
plt.xlabel('Epochs')
plt.ylabel('Training and validation loss')
plt.legend(['Trainnig Loss','Validation Loss'])

# %%
# change the color
y_pred = ANN_model.predict(X_test)

y_pred_orig = scaler_y.inverse_transform(y_pred)
y_test_orig = scaler_y.inverse_transform(y_test)

plt.plot(y_test_orig, y_pred_orig, "^", color = 'b')
plt.xlabel('Model Predictions')
plt.ylabel('True Values')
# Out:
# Text(0, 0.5, 'True Values')

# %%
k = X_test.shape[1]
n = len(X_test)

RMSE = float(format(np.sqrt(mean_squared_error(y_test_orig, y_pred_orig)),'.3f'))
MSE = mean_squared_error(y_test_orig, y_pred_orig)
MAE = mean_absolute_error(y_test_orig, y_pred_orig)
r2 = r2_score(y_test_orig, y_pred_orig)
adj_r2 = 1 - (1-r2) * (n-1)/(n-k)

print('RMSE =',RMSE, 
      '\nMSE =',MSE, 
      '\nMAE =',MAE,
      '\nR2=',r2, 
      '\nAdjusted R2 =',adj_r2)
# Out:
# RMSE = 4810.071
# MSE = 23136788.0
# MAE = 2738.8433
# R2= 0.8509695687821239
# Adjusted R2 = 0.8469572110185657

# %% [markdown]
# ## 9.Random Forest

# %%
from sklearn.model_selection import GridSearchCV
# Create the parameter grid based on the results of random search 
param_grid = {
    'bootstrap': [True],
    'max_depth': [4, 5, 6, 7],
    'max_features': [2, 3, 4],
    'min_samples_leaf': [2, 3, 4],
    'min_samples_split': [3, 4, 5],
    'n_estimators': [10, 30, 50, 100]
}

# Create a based model
rf = RandomForestRegressor(criterion = 'mse')

# Instantiate the grid search model
grid_search_rf = GridSearchCV(estimator = rf, param_grid = param_grid, 
                          cv = 5, n_jobs = -1, verbose = 4)

# %%
grid_search_rf.fit(X_train, y_train)

grid_search_rf.best_params_
# Out:
# Fitting 5 folds for each of 432 candidates, totalling 2160 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    1.9s
# [Parallel(n_jobs=-1)]: Done 160 tasks      | elapsed:    9.8s
# [Parallel(n_jobs=-1)]: Done 406 tasks      | elapsed:   24.3s
# [Parallel(n_jobs=-1)]: Done 748 tasks      | elapsed:   44.5s
# [Parallel(n_jobs=-1)]: Done 1190 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 1728 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=-1)]: Done 2160 out of 2160 | elapsed:  2.2min finished
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_search.py:739: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self.best_estimator_.fit(X, y, **fit_params)
# {'bootstrap': True,
#  'max_depth': 6,
#  'max_features': 4,
#  'min_samples_leaf': 4,
#  'min_samples_split': 5,
#  'n_estimators': 100}

# %%
grid_search_rf_R2 = grid_search_rf.score(X_test,y_test)
grid_search_rf_R2
# Out:
# 0.8790332382641877

# %%
# Predict the value
y_pred = grid_search_rf.predict(X_test)

y_pred_orig = scaler_y.inverse_transform(y_pred)
y_test_orig = scaler_y.inverse_transform(y_test)

# %%
k = X_test.shape[1]
n = len(X_test)

RMSE = float(format(np.sqrt(mean_squared_error(y_test_orig, y_pred_orig)),'.3f'))
MSE = mean_squared_error(y_test_orig, y_pred_orig)
MAE = mean_absolute_error(y_test_orig, y_pred_orig)
r2 = r2_score(y_test_orig, y_pred_orig)
adj_r2 = 1 - (1-r2) * (n-1)/(n-k)

print('RMSE =',RMSE, 
      '\nMSE =',MSE, 
      '\nMAE =',MAE,
      '\nR2=',r2, 
      '\nAdjusted R2 =',adj_r2)
# Out:
# RMSE = 4333.582
# MSE = 18779935.67878772
# MAE = 2512.3312218659057
# R2= 0.8790332461500581
# Adjusted R2 = 0.8757764489310211

# %% [markdown]
# ## 10.XGBoost

# %%
#! pip install xgboost
import xgboost as xgb

# %%
param_grid = {
        'gamma': [0.1,0.3, 0.5, 1],   # regularization parameter 
        'subsample': [0.6, 0.8, 1.0], # % of rows taken to build each tree
        'colsample_bytree': [0.6, 0.8, 1.0], # number of columns used by each tree
        'max_depth': [3, 4, 5], # depth of each tree
        'n_estimaters': [10, 30, 50, 100],
        'learning_rate' :[0.01, 0.03, 0.05]
        }

# %%
xgb_model = xgb.XGBRegressor(objective = 'reg:squarederror')

grid_xgb = GridSearchCV(xgb_model,
                    param_grid,
                    cv = 5, 
                    n_jobs = -1, 
                    verbose = 4)

# %%
grid_xgb.fit(X_train, y_train)

grid_xgb.best_params_
# Out:
# Fitting 5 folds for each of 1296 candidates, totalling 6480 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  38 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:    7.5s
# [Parallel(n_jobs=-1)]: Done 430 tasks      | elapsed:   17.2s
# [Parallel(n_jobs=-1)]: Done 772 tasks      | elapsed:   31.1s
# [Parallel(n_jobs=-1)]: Done 1214 tasks      | elapsed:   49.3s
# [Parallel(n_jobs=-1)]: Done 1752 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 2390 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done 3124 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=-1)]: Done 3958 tasks      | elapsed:  2.9min
# [Parallel(n_jobs=-1)]: Done 4888 tasks      | elapsed:  3.7min
# [Parallel(n_jobs=-1)]: Done 5918 tasks      | elapsed:  4.6min
# [Parallel(n_jobs=-1)]: Done 6480 out of 6480 | elapsed:  5.0min finished
# {'colsample_bytree': 1.0,
#  'gamma': 0.1,
#  'learning_rate': 0.05,
#  'max_depth': 3,
#  'n_estimaters': 10,
#  'subsample': 0.6}

# %%
grid_xgb_R2 = grid_xgb.score(X_test,y_test)
grid_xgb_R2
# Out:
# 0.880884719042577

# %%
# Predict the value
y_pred = grid_xgb.predict(X_test)

y_pred_orig = scaler_y.inverse_transform(y_pred)
y_test_orig = scaler_y.inverse_transform(y_test)

# %%
k = X_test.shape[1]
n = len(X_test)

RMSE = float(format(np.sqrt(mean_squared_error(y_test_orig, y_pred_orig)),'.3f'))
MSE = mean_squared_error(y_test_orig, y_pred_orig)
MAE = mean_absolute_error(y_test_orig, y_pred_orig)
r2 = r2_score(y_test_orig, y_pred_orig)
adj_r2 = 1 - (1-r2) * (n-1)/(n-k)

print('RMSE =',RMSE, 
      '\nMSE =',MSE, 
      '\nMAE =',MAE,
      '\nR2=',r2, 
      '\nAdjusted R2 =',adj_r2)
# Out:
# RMSE = 4300.29
# MSE = 18492496.0
# MAE = 2489.5288
# R2= 0.8808847238110471
# Adjusted R2 = 0.8776777740674984

# %% [markdown]
# ## 11.Summary
# The optimal model is XGBoost with the tunned parameters with the lowest RMSE and Highest R2 (0.881)
